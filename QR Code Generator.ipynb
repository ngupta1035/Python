# %%
# !pip install qrcode[pil]
# Out:
# Collecting qrcode[pil]
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from qrcode[pil]) (0.4.6)
# Requirement already satisfied: pillow>=9.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from qrcode[pil]) (12.2.0)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
#   WARNING: The script qr.exe is installed in 'C:\Users\Narayani G\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\Narayani G\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import qrcode

data = input("Enter text or URL: ")

qr = qrcode.make(data)

qr.save("my_qr_code.png")

print("QR Code generated successfully!")
# Out:
# Enter text or URL:  github.com/ngupta1035
# QR Code generated successfully!

# %%
from PIL import Image
from IPython.display import display

img = Image.open("my_qr_code.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=330x330>
